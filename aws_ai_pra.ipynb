# %% [markdown]
# <a href="https://colab.research.google.com/github/laxmiviveksalveru/ProjectChallenge/blob/main/aws_ai_pra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color=red>**If you plan to take the AWS AI Practitioner exam, I’d like to share some keywords and tips to help you pass this fundamental beta exam**</font>

# %% [markdown]
# ## <font color=blue>**This beta exam consists of 85 questions, with a total score of 1000. To pass, you need to score at least 700. The exam duration is approximately 130 minutes, but non-native English speakers are given an additional 30 minutes. Remember, you only need to score above 700 to pass.**</font>

# %% [markdown]
# **link to apply for the exam**
# https://www.aws.training/Certification

# %% [markdown]
# ![Screenshot 2024-09-10 040137.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-09-10 040814.png](data:image/png;base64,...)

# %% [markdown]
# **Currently, this exam is in beta version, which means AWS is experimenting with new questions to measure the standards for this exam. I suggest that the beta version is a bit harder, with challenging questions and a large question pool (85 questions). However, when the standard version is released by AWS, you can expect more refined questions and a reduced question pool of 65 questions**

# %% [markdown]
# # <font color=green>**Resource to pass this exam with ease** </font>

# %% [markdown]
# https://www.udemy.com/share/10bvGH3@lnd4ODiQOLgoiAH1cfRAVLGt5pbUbn_jbxrPW29b35I_zu0AGLtkgTRg_H6F1XMksg==/   **udemy course by stephean maarek**

# %% [markdown]
# **create aws skill bulider account if you dont have one**
#
# **apply free standard exam prep plan**

# %% [markdown]
# https://www.udemy.com/course/practice-exams-aws-certified-ai-practitioner/?couponCode=OF83024F udemy pratice test

# %% [markdown]
# https://skillbuilder.aws/exam-prep/ai-practitioner

# %% [markdown]
# ![Screenshot 2024-09-10 042714.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-09-10 044219.png](data:image/png;base64,...)**score down complete this concepts**

# %% [markdown]
# **after learning all required concepts take this exam practice questions**

# %% [markdown]
# ![Screenshot 2024-09-10 044443.png](data:image/png;base64,...)

# %% [markdown]
# **Don’t feel underconfident if you score 60 to 70% on a practice exam (20 questions) on your first attempt. Review the concepts from the beginning carefully, using the materials provided in AWS Skill Builder**.
#
# If you score 90% on your first attempt, you are well-prepared.
#
# **Remember, the questions on the exam will differ from those in the AWS official practice tests, so don't just memorize those questions. You will encounter different questions in the actual exam.**

# %% [markdown]
# # <font color=brown>**My opinion on this certificate and my experience  on this foundamental aws ai practitioner exam**</font>

# %% [markdown]
# This exam tests your understanding of AWS AI services and their use cases, including where to apply which services. It also covers some machine learning and AI concepts.

# %% [markdown]
# ## <font color=green>**how questions were in this exam during my attempt**</font>

# %% [markdown]
# * I don't remember all the questions, but I'll give an overview of how they were asked in the exam.

# %% [markdown]
# * The questions I faced in this exam mostly focused on use cases, testing your understanding of where to apply which service. There are no direct questions that you can simply answer by memorizing; you need to understand the concepts

# %% [markdown]
# * In my exam attempt, 70 out of 85 questions were lengthy use case scenarios and options, which were a bit difficult to understand in a short amount of time. They mostly tested a deep understanding of AWS AI service applications. This means they assessed which concepts or AWS AI services you would apply in various scenarios.

# %% [markdown]
# * You should be patient while answering these questions, as their length can be distracting during the exam.

# %% [markdown]
# ## <font color=bright> **TIPS TO PASS THIS EXAM IN SHORT PREPARATION TIME & IN FIRST GO** .

# %% [markdown]
# * **Understand deeply where you would apply each service in real-world use cases, particularly AWS SageMaker and AWS Bedrock.**

# %% [markdown]
# * **Understand deeply about fine-tuning, including where it is applied, when to use it, and the costs associated with fine-tuning compared to other techniques (such as prompt engineering, Retrieval-Augmented Generation (RAG), continuous pre-training, and training models from scratch).**

# %% [markdown]
# * **Know the differences between AWS SageMaker and AWS Bedrock, including when and where to apply each in real-world use cases. Understand their pricing, and also get an overview of how to implement and integrate them with other AWS resources (e.g., S3, etc.)**

# %% [markdown]
# * **MOST QUESTIONS WAS ON AWS BEDROCK & AWS AWS SAGEMAKER UNDERSTANDING OF THEM**

# %% [markdown]
# *  **Read about AWS Q, including AWS Q Developer, AWS Q App, and AWS Q Business**

# %% [markdown]
# * **Understand the basics of machine learning (ML) and deep learning (DL), including reinforcement learning, epochs, recurrent neural networks (RNNs), XGBoost, decision trees, and neural networks. Be familiar with the use cases for each concept and know where to apply them**

# %% [markdown]
# * **Understand prompt engineering techniques, including zero-shot learning, few-shot learning, chain of thought, and in-context learning.**

# %% [markdown]
# * **Understand AWS Lex, AWS Textract, AWS Comprehend, AWS Rekognition, AWS Polly, and AWS Translate, including their use cases.**

# %% [markdown]
# * **Understand the integration of Amazon S3 with AWS Bedrock and AWS SageMaker**

# %% [markdown]
# * If you're unsure about a question, don't leave it unanswered. Make your best guess based on your knowledge and understanding

# %% [markdown]
# # <FONT COLOR=GREEN>**SOME KEYWORDS I REMEMBERED THAT APPARED IN THIS EXAM**

# %% [markdown]
# **REALWORLD USECASE OF NN,RNN,DECISIONTREE,XGBOOST ETC:-**

# %% [markdown]
# * EXAMPLE:-20 CATEGORY OF HUMAN GENES  YOU NEED TO CLASSIFY THEM.....ETC :-NEURAL NETWORK

# %% [markdown]
# **BATCH,REAL TIME,ASYNCHRONUES ,SYNCHRONOUS,SERVLESS.(LIKE CHECK RESPONSE TIME(60,1HR), PAYPLOAD SIZE(SMALL,LARGE PAYLOAD))**

# %% [markdown]
# * EXAMPLE :- Near TO REAL TIME RESPONSE LESS THAN 1HR AND HAVE LARGE UPLOAD :-asynchronous.

# %% [markdown]
# **CONCEPT OF SUPERVISED,UNSUPERVISED ,REINFORMENT LEARNING**

# %% [markdown]
# * EXAMPLE:-SELF LEARNING MACHANISM :-REINFORMENT LEARNING

# %% [markdown]
# **OPERATION OVERHEAD (PROMPT ENGINEERING,RAG,FINE TUNING,COUNTINUES PRETRAINING,TRAINING FROM STARTING)**
# * :-PROMPT ENGINEERING EASY THAN RAG IS EASY THAN FINE TUNING ETC....

# %% [markdown]
# **BEDROCK WITH FINE TUNING& PRICING(CUSTOM MODEL)**

# %% [markdown]
# *  imagine a security system designed to identify thieves based on past data. If the system's training data mostly consists of cases involving people from a specific demographic (e.g., individuals from a certain race or socioeconomic background), it can develop :-**sample bias**.

# %% [markdown]
# **TUNING PARAMETER LIKE TOP P,TOP K,TEMPERATURE ETC**
# * Real-Life Examples of Use Cases
#  Chatbots: Use Top-k and Temperature to balance between coherence and creativity in conversations.
#
#  Content Generation: For creative writing, you may set a high Temperature and use Top-p to allow the model to generate more varied and imaginative content.
#
#   Factual Q&A: You might use a low Temperature, small Top-k, and Stop Sequence to ensure the responses are accurate and concise.
#
#   Text Summarization: Set a shorter Response Length to generate summaries within a certain limit.

# %% [markdown]
# **Guardrails in AWS Bedrock**

# %% [markdown]
# * Use Case: Prevent the generation of inappropriate, biased, or harmful content.
#
#   Example: Setting up filters to detect and remove any potentially offensive or unwanted outputs from the model.

# %% [markdown]
# **ROUGE, BLEU, and BERTScore**
# * EXAMPLE:-used in text summarization tasks(ROUGE),It was originally developed for machine translation evaluation:-BLUE,BERTScore: Focuses on semantic similarity

# %% [markdown]
# **ENVIRONMENTAL FRIENDLY**
# EXAMPLE:-AWS’s environmentally friendly practices and utilizing Graviton-based instances

# %% [markdown]
# <FONT COLOR=RED>**MOST QUESTIONS I FACED  WAS OF MULTIPLE CONCEPT COMBINED WITH AWS BEDROCK & AWS SAGEMAKER USECASES**</FONT>

# %% [markdown]
# ##<FONT COLOR=BLUE>MY QUICK SHORT KEYWORDS& NOTES

# %% [markdown]
# **Tokens and Embeddings:**
#
# **Tokens: Basic units of text, such as words or subwords, used in NLP models.**
#
# **Embeddings: Representations of tokens in a continuous vector space, capturing semantic meanings.**

# %% [markdown]
# ✅<font color=red>Tokens: Basic units of text, such as words or subwords, Embeddings: Representations of tokens in a continuous vector space, capturing semantic meanings.

# %% [markdown]
# **Supervised Learning: Trains on labeled data (e.g., classification, regression).
# Unsupervised Learning: Finds hidden patterns in unlabeled data (e.g., clustering, dimensionality reduction).
# Reinforcement Learning: Learns by interacting with an environment to maximize cumulative reward.**

# %% [markdown]
# <font color=red>SELF LEARNING MACHANISM:-**REINFORCEMENT LEARNING** </font>

# %% [markdown]
# AWS Services:
#
# Amazon SageMaker: Provides tools for building, training, and deploying ML models.
#
# Amazon Transcribe: Converts speech to text.
#
# Amazon Translate: Translates text between languages.
#
# Amazon Comprehend: Analyzes text for sentiment, entities, and key phrases.
#
# Amazon Lex: Builds conversational interfaces using voice and text.
#
# Amazon Polly: Converts text to lifelike speech.

# %% [markdown]
# ✅ <font color=red>direct sentiment analysis services similar to **Amazon Comprehend**, you can use:
#
# 1. **Amazon Translate (Custom Language Models)**

# %% [markdown]
# Pipeline Stages:
#
# Data Collection: Gathering raw data from various sources.
#
# Exploratory Data Analysis (EDA): Analyzing data to understand its structure and patterns.
#
# Data Pre-Processing: Cleaning and transforming data for model training.
#
# Feature Engineering: Creating features that enhance model performance.
#
# Model Training: Using algorithms to learn from the data.
#
# Hyperparameter Tuning: Adjusting model parameters to improve performance.
#
# Evaluation: Assessing model performance using metrics.
#
# Deployment: Integrating the model into production systems.
#
# Monitoring: Tracking model performance and making updates as needed.

# %% [markdown]
# **AWS Services:**
#
# **Amazon SageMaker: End-to-end service for building, training, and deploying ML models.**
#
# **Amazon SageMaker Data Wrangler: Simplifies data preparation.**
#
# **Amazon SageMaker Feature Store: Manages and retrieves features for ML models**.
#
# **Amazon SageMaker Model Monitor: Monitors model performance in production**

# %% [markdown]
# Generative Models:
#
# Transformer-based LLMs: Models like GPT-3 that generate coherent and contextually relevant text based on input.
# Diffusion Models: Generate high-quality images by iteratively refining noisy data.
# Multi-Modal Models: Handle multiple types of data (text, image, audio) to perform complex tasks.

# %% [markdown]
# ✅ <font color="red">Multi-Modal Models: Handle multiple types of data (text, image, audio) to perform complex tasks.</font>

# %% [markdown]
# Foundation Model Lifecycle:
#
# Data Selection: Choosing diverse and representative data for training.
#
# Model Selection: Choosing appropriate model architectures and techniques.
#
# Pre-Training: Training on large datasets to learn general patterns.
#
# Fine-Tuning: Adjusting the model on domain-specific data to improve performance.
#
# Evaluation: Assessing model quality and performance.
#
# Deployment: Implementing the model in real-world applications.
#
# Feedback: Gathering user feedback to refine and improve the model.

# %% [markdown]
# ✅<FONT COLOR=RED>Generative AI refers to algorithms that can create new data instances that resemble a given training set. Unlike traditional AI, which is designed to recognize patterns and make predictions based on existing data, generative AI focuses on generating n

# %% [markdown]
# Limitations of Generative AI

# %% [markdown]
# ✅<FONT COLOR=RED>Hallucinations: Generative models might produce incorrect or nonsensical outputs.</FONT>

# %% [markdown]
# Inference Parameters:
#
# Temperature: Controls the randomness of model outputs.
# Input/Output Length: Affects the length and detail of generated responses.
# Retrieval Augmented Generation (RAG):
#
# Definition: A technique that combines retrieval of relevant information with generative capabilities to enhance response quality.
# Business Applications: Improving search results, enhancing knowledge base queries.

# %% [markdown]
# Effective Prompt Engineering
# Techniques:
#
# Chain-of-Thought: Step-by-step reasoning to improve model responses.
#
# Zero-Shot Learning: Model performs tasks without prior examples.
#
# Few-Shot Learning: Model is provided with a few examples to generalize tasks.
#
# Prompt Templates: Predefined structures to guide model responses.
#
# Risks and Limitations:
#
#
# Exposure: Risk of sensitive information leakage.
#
# Poisoning: Deliberate manipulation of training data to degrade model performance.
#
# Hijacking: Malicious input causing unintended behavior.
#
# Jailbreaking: Bypassing model constraints or limitations.

# %% [markdown]
# Training and Fine-Tuning Foundation Models
# Processes:
#
# Pre-Training: Training on large datasets to capture general knowledge.
#
# Fine-Tuning: Tailoring the model for specific tasks or domains.
#
# Continuous Pre-Training: Updating the model with new data over time.

# %% [markdown]
# **Analytics:**
#
# AWS Data Exchange: Marketplace for data.
#
#
#
# AWS Glue: ETL service for data preparation.
# AWS Glue DataBrew: Visual data preparation tool.
#
# AWS Lake Formation: Data lake creation and management.
#
# Amazon OpenSearch Service: Managed search and analytics service.
#
# Amazon QuickSight: Business analytics and visualization.
#
# Compute:
# Amazon EC2: Scalable virtual servers in the cloud.
#
# Database:
# Amazon DocumentDB (with MongoDB compatibility): Managed document database.
#
# Amazon DynamoDB: Managed NoSQL database.
#
# Amazon ElastiCache: In-memory caching.
#
# Amazon MemoryDB: Managed Redis-compatible in-memory database
#
# Amazon Neptune: Managed graph database.
#
#
# Amazon RDS: Managed relational database service.
#
# Machine Learning:
#
# Amazon Augmented AI (Amazon A2I): Human-in-the-loop machine learning.
#
# Amazon Bedrock: Foundation model service.
#
# Amazon Comprehend: Natural language processing.
#
# Amazon Fraud Detector: Fraud detection.
#
# Amazon Kendra: Enterprise search service.
#
#
# Amazon Lex: Build conversational interfaces.
#
# Amazon Personalize: Personalization and recommendations.
#
# Amazon Polly: Text-to-speech service.
#
# Amazon Q: Conversational AI service.
#
# Amazon Rekognition: Image and video analysis.
#
#
# Amazon SageMaker: End-to-end machine learning service.
#
#
# Amazon Textract: Extract text and data from documents.
#
# Amazon Transcribe: Speech-to-text service.
#
# Amazon Translate: Language translation.
#
#
# Management and Governance:
#
# AWS CloudTrail: Monitoring and logging of AWS API calls.
#
# **Amazon CloudWatch:** Monitoring and observabilitY
# <FONT COLOR=GREEN>**Amazon CloudWatch provides essential monitoring and logging capabilities for both AWS SageMaker and Amazon Bedrock, ensuring smooth operation, resource optimization, and real-time visibility into model performance.**</FONT>
#
# <FONT COLOR=RED>**In SageMaker, CloudWatch tracks training jobs, inference endpoints, and resource utilization, helping optimize model development and deployment.
# In Bedrock, CloudWatch monitors API invocations, latency, and errors, ensuring the performance of foundation models and generative AI workflows.
# Automated Monitoring and Alerts: Set up CloudWatch alarms and dashboards to monitor key metrics and respond quickly to performance issues in both SageMaker and Bedrock.**</FONT>
#
# AWS Config: Resource configuration tracking.
#
# AWS Trusted Advisor: Best practice recommendations.
#
# AWS Well-Architected Tool: Review and improve cloud architecture.
#
#
# Networking and Content Delivery:
#
#
# Amazon CloudFront: Content delivery network.
#
# Amazon VPC: Virtual private cloud for isolated networking.
#
#
# <FONT COLOR=RED>Security, Identity, and Compliance:</FONT>
#
#
# AWS Artifact: Access to compliance reports.
#
# AWS Audit Manager: Automated audit preparation.
#
# **AWS Identity and Access Management (IAM): Manage access to AWS services.**
# <FONT COLOR=GREEN>IAM enables secure, fine-grained control over who can perform operations and access data in Bedrock and SageMaker, providing a flexible and scalable way to manage permissions across your AI and ML workflows.</FONT>
#
# Amazon Inspector: Security assessments.
#
# AWS Key Management Service (KMS): Key management and encryption.
#
# **Amazon Macie: Data protection and privacy.**
#
# <FONT COLOR=GREEN>AWS Macie is critical in maintaining data security and privacy when working with large datasets in Amazon SageMaker and Amazon Bedrock.
# Macie helps you identify and manage sensitive data in S3 before it is used in machine learning or generative AI models, ensuring compliance with privacy regulations.</FONT>
#
# <FONT COLOR=GREEN>By integrating Macie with your SageMaker and Bedrock workflows, you can automate the detection and protection of sensitive data, reducing the risk of data breaches or non-compliance.</FONT>
#
# AWS Secrets Manager: Manage secrets and credentials.
#
# <FONT COLOR=RED>Storage:</FONT>
#
# <FONT COLOR=GREEN>**Amazon S3: Scalable object storage.**</FONT>
# **Amazon S3 acts as the central repository for storing and managing datasets, model artifacts, and outputs in both Amazon Bedrock and AWS SageMaker workflows.**
#
# **Data Security, Scalability, and Availability are major benefits of integrating S3 with these AI/ML services.**
#
# **Seamless Access to Data: Both Bedrock and SageMaker can access data directly from S3 without any complex setup, making the integration straightforward for building and scaling AI/ML applications.**
#
#
# Amazon S3 Glacier: Low-cost archival storage.

# %% [markdown]
# <FONT COLOR=RED>the company is using a foundation model from Amazon Bedrock that has been trained on data, including some biased data, and now they want to ensure the model does not produce biased outputs</FONT>

# %% [markdown]
# Pre-train from the Start (Option 1)
#
# Fine-tuning the Model (Option 2)
#
# Reinforcement Learning from Human Feedback (RLHF) (OPTION 3)
#
# Continuous Pre-Training (OPTION 4)

# %% [markdown]
# <FONT COLOR=GREEN> RLHF would likely be the recommended choice to ensure the model no longer produces biased outputs.</FONT>

# %% [markdown]
# **biases can affect the fairness, accuracy, and trustworthiness of the model’s predictions**

# %% [markdown]
# **Algorithmic Bias**
# Algorithmic bias occurs when the machine learning (ML) algorithm itself introduces or amplifies biases, leading to unfair or skewed outcomes. This bias can stem from the design or operation of the algorithm, regardless of the data used.

# %% [markdown]
#  **Sample Bias (Sampling Bias)**
#  Sample bias, or sampling bias, occurs when the data collected or selected for training the model does not adequately represent the population or use case. This results in the model making predictions that are biased toward certain groups or categories

# %% [markdown]
# **Measurement Bias**
# Measurement bias occurs when there are errors or inconsistencies in how features or outcomes are measured. This can lead to the model learning from incorrect or skewed data, which results in biased predictions.

# %% [markdown]
# **Recency Bias**:-Recency bias occurs when a model or system disproportionately gives more weight or importance to recent events or data points, while undervaluing older or historical data

# %% [markdown]
# $ **Steps for Custom Fine-Tuning in Amazon Bedrock
# Choose the Foundation Model:** $
#
# Select the Right Model: Based on your task, you can choose from a variety of foundation models on Bedrock. These could be language models (like AWS Titan or Claude) or multi-modal models (like Stable Diffusion for image generation).
# Pre-trained Knowledge: The selected model has already been pre-trained on large, diverse datasets. Fine-tuning allows you to tailor this pre-trained knowledge to your specific use case.
# Prepare Your Dataset:
#
# Gather Domain-Specific Data: Collect and curate a dataset that reflects the specific domain or tasks you want the model to excel at. For example, if you’re building a legal chatbot, you would gather legal documents and question-answer pairs specific to that domain.
# Label Your Data: Ensure that your data is properly labeled if you are performing supervised fine-tuning (e.g., labeled sentiment data, product classifications).
# Data Storage in S3: Store your dataset in Amazon S3, which Bedrock can access during the fine-tuning process.
# Fine-Tuning Process:
#
# Initiate the Fine-Tuning Job: Bedrock provides APIs to initiate fine-tuning for your chosen foundation model. You pass your dataset stored in S3, and Bedrock handles the fine-tuning process.
# Hyperparameter Tuning: You can adjust hyperparameters (such as learning rate, batch size) during the fine-tuning process to optimize model performance on your data.
# Monitor Training Progress: Use Amazon CloudWatch for real-time monitoring of the fine-tuning job’s progress. You can track metrics like accuracy, loss, and resource utilization.
# Evaluate the Fine-Tuned Model:
#
# Test on Evaluation Data: After fine-tuning, evaluate the model on a separate validation dataset to assess its performance. This helps ensure that the model generalizes well to new data.
# Adjust and Refine: If needed, you can further fine-tune the model by adjusting hyperparameters or adding more training data to improve performance.
# Deploy the Fine-Tuned Model:
#
# Model Deployment: Once fine-tuning is complete and the model meets performance requirements, you can deploy the fine-tuned model for real-time or batch inference.
# Monitor and Scale: Use Amazon Bedrock’s API to integrate the fine-tuned model into your applications. Monitor its performance and scale resources as needed based on usage.

# %% [markdown]
# ![Screenshot 2024-09-10 151935.png](data:image/png;base64,...)

# %% [markdown]
# https://colab.research.google.com/drive/1h_DELx2V5rhb4TByhUra8O8lZmtPabdf#scrollTo=KYPmNK-E9_Vx   i made this rough notes for my exam preperation  but most of it not covered all exam questions because most questions was on usescase and deep understanding of concept application (bedrock,sagemaker,prompt etc..)
